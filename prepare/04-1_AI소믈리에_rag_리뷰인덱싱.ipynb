# %% [markdown]
# # 케글의 와인 데이터

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
OPENAI_EMBEDDING_MODEL = os.getenv("OPENAI_EMBEDDING_MODEL")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_NAMESPACE = os.getenv("PINECONE_NAMESPACE")

# %% [markdown]
# ## document loader

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader('./wine_reviews/winemag-data-130k-v2.csv')
docs = loader.load()
for i, d in enumerate(docs[:2]):
    print(i, d)
# Out:
# 0 page_content=': 0
# country: Italy
# description: Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
# designation: Vulkà Bianco
# points: 87
# price:
# province: Sicily & Sardinia
# region_1: Etna
# region_2:
# taster_name: Kerin O’Keefe
# taster_twitter_handle: @kerinokeefe
# title: Nicosia 2013 Vulkà Bianco  (Etna)
# variety: White Blend
# winery: Nicosia' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 0}
# 1 page_content=': 1
# country: Portugal
# description: This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled out with juicy red berry fruits and freshened with acidity. It's  already drinkable, although it will certainly be better from 2016.
# designation: Avidagos
# points: 87
# price: 15.0
# province: Douro
# region_1:
# region_2:
# taster_name: Roger Voss
# taster_twitter_handle: @vossroger
# title: Quinta dos Avidagos 2011 Avidagos Red (Douro)
# variety: Portuguese Red
# winery: Quinta dos Avidagos' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 1}

# %%
len(docs)
# Out:
# 129971

# %% [markdown]
# ## embedding 모델 객체 생성

# %%
# embedding 모델 객체 생성
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model=OPENAI_EMBEDDING_MODEL)

# %% [markdown]
# ## Pinecone객체, index객체 생성

# %%
from pinecone import Pinecone, ServerlessSpec


# Pinecone 클라이언트를 초기화(객체생성)
pc = Pinecone(api_key=PINECONE_API_KEY)

# %%
## index 있으면 삭제

# index_name = PINECONE_INDEX_NAME

# for idx in pc.list_indexes():
#     if idx.name == index_name:
#         pc.delete_index(index_name)

# %% [markdown]
# - pinecone 객체 생성, index 생성

# %%
# pinecone에 index list 가져오기
existing_indexes = pc.list_indexes()

# 이름만 추출
index_names = [index['name'] for index in existing_indexes.indexes]
# print(index_names)

# index 이름이 존재 하지 않으면 생성
if PINECONE_INDEX_NAME not in index_names:
    pc.create_index(
        name=PINECONE_INDEX_NAME,
        dimension=1536,  # 모델 차원, openapi embeding model을 사용함. 정확하게 일치
        metric="cosine",  # 모델 메트릭, openapi embeding model 에서 사용하는 것 확인
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )
    print(f"Index '{PINECONE_INDEX_NAME}' created successfully.")
else:
    print(f"Index '{PINECONE_INDEX_NAME}' already exists.")
# Out:
# Index 'wine-reviews' created successfully.

# %% [markdown]
# ## split 객체 생성

# %%
# split하기
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 텍스트 분할기 설정 (예: 1000자씩 분할)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=100,
    # length_function=tiktoken_len,  # 토큰 기반 길이 측정    
    length_function=len,  # 문자수   
    separators=["\n\n", "\n", " ", ""]
    )

# 문서를 분할
chunks = text_splitter.split_documents(docs)

# %%
len(chunks)
# Out:
# 129982

# %% [markdown]
# ## 배치 크기 단위로 저장
# - langchain_pinecone 으로 벡터 DB에 저장

# %%
# vector sotre에 저장(2시간정도 걸림)
from langchain_pinecone import PineconeVectorStore

batch_size = 200
  # 한 번에 처리할 문서 수

for i in range(0, len(chunks), batch_size):
    batch_docs = chunks[i:i+batch_size]
    
    if i == 0:
        # 첫 번째 배치로 벡터 스토어 생성
        vector_store = PineconeVectorStore.from_documents(
            batch_docs,            # batch_size 수 만큼의 chunk
            embedding=embeddings,  # 임베딩 벡터로 변환
            index_name=PINECONE_INDEX_NAME,   # index 이름
            namespace=PINECONE_NAMESPACE      
        )
    else:
        # 이후 배치는 기존 벡터 스토어에 추가, # 내부적으로 임베딩 벡터로 변환
        vector_store.add_documents(batch_docs)    
    
    print(f"배치 {i//batch_size + 1} 완료: {len(batch_docs)}개 문서 업로드")
# Out:
# 배치 1 완료: 200개 문서 업로드
# 배치 2 완료: 200개 문서 업로드
# 배치 3 완료: 200개 문서 업로드
# 배치 4 완료: 200개 문서 업로드
# 배치 5 완료: 200개 문서 업로드
# 배치 6 완료: 200개 문서 업로드
# 배치 7 완료: 200개 문서 업로드
# 배치 8 완료: 200개 문서 업로드
# 배치 9 완료: 200개 문서 업로드
# 배치 10 완료: 200개 문서 업로드
# 배치 11 완료: 200개 문서 업로드
# 배치 12 완료: 200개 문서 업로드
# 배치 13 완료: 200개 문서 업로드
# 배치 14 완료: 200개 문서 업로드
# 배치 15 완료: 200개 문서 업로드
# 배치 16 완료: 200개 문서 업로드
# 배치 17 완료: 200개 문서 업로드
# 배치 18 완료: 200개 문서 업로드
# 배치 19 완료: 200개 문서 업로드
# 배치 20 완료: 200개 문서 업로드
# 배치 21 완료: 200개 문서 업로드
# 배치 22 완료: 200개 문서 업로드
# 배치 23 완료: 200개 문서 업로드
# 배치 24 완료: 200개 문서 업로드
# 배치 25 완료: 200개 문서 업로드
# 배치 26 완료: 200개 문서 업로드
# 배치 27 완료: 200개 문서 업로드
# 배치 28 완료: 200개 문서 업로드
# 배치 29 완료: 200개 문서 업로드
# 배치 30 완료: 200개 문서 업로드
# 배치 31 완료: 200개 문서 업로드
# 배치 32 완료: 200개 문서 업로드
# 배치 33 완료: 200개 문서 업로드
# 배치 34 완료: 200개 문서 업로드
# 배치 35 완료: 200개 문서 업로드
# 배치 36 완료: 200개 문서 업로드
# 배치 37 완료: 200개 문서 업로드
# 배치 38 완료: 200개 문서 업로드
# 배치 39 완료: 200개 문서 업로드
# 배치 40 완료: 200개 문서 업로드
# 배치 41 완료: 200개 문서 업로드
# 배치 42 완료: 200개 문서 업로드
# 배치 43 완료: 200개 문서 업로드
# 배치 44 완료: 200개 문서 업로드
# 배치 45 완료: 200개 문서 업로드
# 배치 46 완료: 200개 문서 업로드
# 배치 47 완료: 200개 문서 업로드
# 배치 48 완료: 200개 문서 업로드
# 배치 49 완료: 200개 문서 업로드
# 배치 50 완료: 200개 문서 업로드
# 배치 51 완료: 200개 문서 업로드
# 배치 52 완료: 200개 문서 업로드
# 배치 53 완료: 200개 문서 업로드
# 배치 54 완료: 200개 문서 업로드
# 배치 55 완료: 200개 문서 업로드
# 배치 56 완료: 200개 문서 업로드
# 배치 57 완료: 200개 문서 업로드
# 배치 58 완료: 200개 문서 업로드
# 배치 59 완료: 200개 문서 업로드
# 배치 60 완료: 200개 문서 업로드
# 배치 61 완료: 200개 문서 업로드
# 배치 62 완료: 200개 문서 업로드
# 배치 63 완료: 200개 문서 업로드
# 배치 64 완료: 200개 문서 업로드
# 배치 65 완료: 200개 문서 업로드
# 배치 66 완료: 200개 문서 업로드
# 배치 67 완료: 200개 문서 업로드
# 배치 68 완료: 200개 문서 업로드
# 배치 69 완료: 200개 문서 업로드
# 배치 70 완료: 200개 문서 업로드
# 배치 71 완료: 200개 문서 업로드
# 배치 72 완료: 200개 문서 업로드
# 배치 73 완료: 200개 문서 업로드
# 배치 74 완료: 200개 문서 업로드
# 배치 75 완료: 200개 문서 업로드
# 배치 76 완료: 200개 문서 업로드
# 배치 77 완료: 200개 문서 업로드
# 배치 78 완료: 200개 문서 업로드
# 배치 79 완료: 200개 문서 업로드
# 배치 80 완료: 200개 문서 업로드
# 배치 81 완료: 200개 문서 업로드
# 배치 82 완료: 200개 문서 업로드
# 배치 83 완료: 200개 문서 업로드
# 배치 84 완료: 200개 문서 업로드
# 배치 85 완료: 200개 문서 업로드
# 배치 86 완료: 200개 문서 업로드
# 배치 87 완료: 200개 문서 업로드
# 배치 88 완료: 200개 문서 업로드
# 배치 89 완료: 200개 문서 업로드
# 배치 90 완료: 200개 문서 업로드
# 배치 91 완료: 200개 문서 업로드
# 배치 92 완료: 200개 문서 업로드
# 배치 93 완료: 200개 문서 업로드
# 배치 94 완료: 200개 문서 업로드
# 배치 95 완료: 200개 문서 업로드
# 배치 96 완료: 200개 문서 업로드
# 배치 97 완료: 200개 문서 업로드
# 배치 98 완료: 200개 문서 업로드
# 배치 99 완료: 200개 문서 업로드
# 배치 100 완료: 200개 문서 업로드
# 배치 101 완료: 200개 문서 업로드
# 배치 102 완료: 200개 문서 업로드
# 배치 103 완료: 200개 문서 업로드
# 배치 104 완료: 200개 문서 업로드
# 배치 105 완료: 200개 문서 업로드
# 배치 106 완료: 200개 문서 업로드
# 배치 107 완료: 200개 문서 업로드
# 배치 108 완료: 200개 문서 업로드
# 배치 109 완료: 200개 문서 업로드
# 배치 110 완료: 200개 문서 업로드
# 배치 111 완료: 200개 문서 업로드
# 배치 112 완료: 200개 문서 업로드
# 배치 113 완료: 200개 문서 업로드
# 배치 114 완료: 200개 문서 업로드
# 배치 115 완료: 200개 문서 업로드
# 배치 116 완료: 200개 문서 업로드
# 배치 117 완료: 200개 문서 업로드
# 배치 118 완료: 200개 문서 업로드
# 배치 119 완료: 200개 문서 업로드
# 배치 120 완료: 200개 문서 업로드
# 배치 121 완료: 200개 문서 업로드
# 배치 122 완료: 200개 문서 업로드
# 배치 123 완료: 200개 문서 업로드
# 배치 124 완료: 200개 문서 업로드
# 배치 125 완료: 200개 문서 업로드
# 배치 126 완료: 200개 문서 업로드
# 배치 127 완료: 200개 문서 업로드
# 배치 128 완료: 200개 문서 업로드
# 배치 129 완료: 200개 문서 업로드
# 배치 130 완료: 200개 문서 업로드
# 배치 131 완료: 200개 문서 업로드
# 배치 132 완료: 200개 문서 업로드
# 배치 133 완료: 200개 문서 업로드
# 배치 134 완료: 200개 문서 업로드
# 배치 135 완료: 200개 문서 업로드
# 배치 136 완료: 200개 문서 업로드
# 배치 137 완료: 200개 문서 업로드
# 배치 138 완료: 200개 문서 업로드
# 배치 139 완료: 200개 문서 업로드
# 배치 140 완료: 200개 문서 업로드
# 배치 141 완료: 200개 문서 업로드
# 배치 142 완료: 200개 문서 업로드
# 배치 143 완료: 200개 문서 업로드
# 배치 144 완료: 200개 문서 업로드
# 배치 145 완료: 200개 문서 업로드
# 배치 146 완료: 200개 문서 업로드
# 배치 147 완료: 200개 문서 업로드
# 배치 148 완료: 200개 문서 업로드
# 배치 149 완료: 200개 문서 업로드
# 배치 150 완료: 200개 문서 업로드
# 배치 151 완료: 200개 문서 업로드
# 배치 152 완료: 200개 문서 업로드
# 배치 153 완료: 200개 문서 업로드
# 배치 154 완료: 200개 문서 업로드
# 배치 155 완료: 200개 문서 업로드
# 배치 156 완료: 200개 문서 업로드
# 배치 157 완료: 200개 문서 업로드
# 배치 158 완료: 200개 문서 업로드
# 배치 159 완료: 200개 문서 업로드
# 배치 160 완료: 200개 문서 업로드
# 배치 161 완료: 200개 문서 업로드
# 배치 162 완료: 200개 문서 업로드
# 배치 163 완료: 200개 문서 업로드
# 배치 164 완료: 200개 문서 업로드
# 배치 165 완료: 200개 문서 업로드
# 배치 166 완료: 200개 문서 업로드
# 배치 167 완료: 200개 문서 업로드
# 배치 168 완료: 200개 문서 업로드
# 배치 169 완료: 200개 문서 업로드
# 배치 170 완료: 200개 문서 업로드
# 배치 171 완료: 200개 문서 업로드
# 배치 172 완료: 200개 문서 업로드
# 배치 173 완료: 200개 문서 업로드
# 배치 174 완료: 200개 문서 업로드
# 배치 175 완료: 200개 문서 업로드
# 배치 176 완료: 200개 문서 업로드
# 배치 177 완료: 200개 문서 업로드
# 배치 178 완료: 200개 문서 업로드
# 배치 179 완료: 200개 문서 업로드
# 배치 180 완료: 200개 문서 업로드
# 배치 181 완료: 200개 문서 업로드
# 배치 182 완료: 200개 문서 업로드
# 배치 183 완료: 200개 문서 업로드
# 배치 184 완료: 200개 문서 업로드
# 배치 185 완료: 200개 문서 업로드
# 배치 186 완료: 200개 문서 업로드
# 배치 187 완료: 200개 문서 업로드
# 배치 188 완료: 200개 문서 업로드
# 배치 189 완료: 200개 문서 업로드
# 배치 190 완료: 200개 문서 업로드
# 배치 191 완료: 200개 문서 업로드
# 배치 192 완료: 200개 문서 업로드
# 배치 193 완료: 200개 문서 업로드
# 배치 194 완료: 200개 문서 업로드
# 배치 195 완료: 200개 문서 업로드
# 배치 196 완료: 200개 문서 업로드
# 배치 197 완료: 200개 문서 업로드
# 배치 198 완료: 200개 문서 업로드
# 배치 199 완료: 200개 문서 업로드
# 배치 200 완료: 200개 문서 업로드
# 배치 201 완료: 200개 문서 업로드
# 배치 202 완료: 200개 문서 업로드
# 배치 203 완료: 200개 문서 업로드
# 배치 204 완료: 200개 문서 업로드
# 배치 205 완료: 200개 문서 업로드
# 배치 206 완료: 200개 문서 업로드
# 배치 207 완료: 200개 문서 업로드
# 배치 208 완료: 200개 문서 업로드
# 배치 209 완료: 200개 문서 업로드
# 배치 210 완료: 200개 문서 업로드
# 배치 211 완료: 200개 문서 업로드
# 배치 212 완료: 200개 문서 업로드
# 배치 213 완료: 200개 문서 업로드
# 배치 214 완료: 200개 문서 업로드
# 배치 215 완료: 200개 문서 업로드
# 배치 216 완료: 200개 문서 업로드
# 배치 217 완료: 200개 문서 업로드
# 배치 218 완료: 200개 문서 업로드
# 배치 219 완료: 200개 문서 업로드
# 배치 220 완료: 200개 문서 업로드
# 배치 221 완료: 200개 문서 업로드
# 배치 222 완료: 200개 문서 업로드
# 배치 223 완료: 200개 문서 업로드
# 배치 224 완료: 200개 문서 업로드
# 배치 225 완료: 200개 문서 업로드
# 배치 226 완료: 200개 문서 업로드
# 배치 227 완료: 200개 문서 업로드
# 배치 228 완료: 200개 문서 업로드
# 배치 229 완료: 200개 문서 업로드
# 배치 230 완료: 200개 문서 업로드
# 배치 231 완료: 200개 문서 업로드
# 배치 232 완료: 200개 문서 업로드
# 배치 233 완료: 200개 문서 업로드
# 배치 234 완료: 200개 문서 업로드
# 배치 235 완료: 200개 문서 업로드
# 배치 236 완료: 200개 문서 업로드
# 배치 237 완료: 200개 문서 업로드
# 배치 238 완료: 200개 문서 업로드
# 배치 239 완료: 200개 문서 업로드
# 배치 240 완료: 200개 문서 업로드
# 배치 241 완료: 200개 문서 업로드
# 배치 242 완료: 200개 문서 업로드
# 배치 243 완료: 200개 문서 업로드
# 배치 244 완료: 200개 문서 업로드
# 배치 245 완료: 200개 문서 업로드
# 배치 246 완료: 200개 문서 업로드
# 배치 247 완료: 200개 문서 업로드
# 배치 248 완료: 200개 문서 업로드
# 배치 249 완료: 200개 문서 업로드
# 배치 250 완료: 200개 문서 업로드
# 배치 251 완료: 200개 문서 업로드
# 배치 252 완료: 200개 문서 업로드
# 배치 253 완료: 200개 문서 업로드
# 배치 254 완료: 200개 문서 업로드
# 배치 255 완료: 200개 문서 업로드
# 배치 256 완료: 200개 문서 업로드
# 배치 257 완료: 200개 문서 업로드
# 배치 258 완료: 200개 문서 업로드
# 배치 259 완료: 200개 문서 업로드
# 배치 260 완료: 200개 문서 업로드
# 배치 261 완료: 200개 문서 업로드
# 배치 262 완료: 200개 문서 업로드
# 배치 263 완료: 200개 문서 업로드
# 배치 264 완료: 200개 문서 업로드
# 배치 265 완료: 200개 문서 업로드
# 배치 266 완료: 200개 문서 업로드
# 배치 267 완료: 200개 문서 업로드
# 배치 268 완료: 200개 문서 업로드
# 배치 269 완료: 200개 문서 업로드
# 배치 270 완료: 200개 문서 업로드
# 배치 271 완료: 200개 문서 업로드
# 배치 272 완료: 200개 문서 업로드
# 배치 273 완료: 200개 문서 업로드
# 배치 274 완료: 200개 문서 업로드
# 배치 275 완료: 200개 문서 업로드
# 배치 276 완료: 200개 문서 업로드
# 배치 277 완료: 200개 문서 업로드
# 배치 278 완료: 200개 문서 업로드
# 배치 279 완료: 200개 문서 업로드
# 배치 280 완료: 200개 문서 업로드
# 배치 281 완료: 200개 문서 업로드
# 배치 282 완료: 200개 문서 업로드
# 배치 283 완료: 200개 문서 업로드
# 배치 284 완료: 200개 문서 업로드
# 배치 285 완료: 200개 문서 업로드
# 배치 286 완료: 200개 문서 업로드
# 배치 287 완료: 200개 문서 업로드
# 배치 288 완료: 200개 문서 업로드
# 배치 289 완료: 200개 문서 업로드
# 배치 290 완료: 200개 문서 업로드
# 배치 291 완료: 200개 문서 업로드
# 배치 292 완료: 200개 문서 업로드
# 배치 293 완료: 200개 문서 업로드
# 배치 294 완료: 200개 문서 업로드
# 배치 295 완료: 200개 문서 업로드
# 배치 296 완료: 200개 문서 업로드
# 배치 297 완료: 200개 문서 업로드
# 배치 298 완료: 200개 문서 업로드
# 배치 299 완료: 200개 문서 업로드
# 배치 300 완료: 200개 문서 업로드
# 배치 301 완료: 200개 문서 업로드
# 배치 302 완료: 200개 문서 업로드
# 배치 303 완료: 200개 문서 업로드
# 배치 304 완료: 200개 문서 업로드
# 배치 305 완료: 200개 문서 업로드
# 배치 306 완료: 200개 문서 업로드
# 배치 307 완료: 200개 문서 업로드
# 배치 308 완료: 200개 문서 업로드
# 배치 309 완료: 200개 문서 업로드
# 배치 310 완료: 200개 문서 업로드
# 배치 311 완료: 200개 문서 업로드
# 배치 312 완료: 200개 문서 업로드
# 배치 313 완료: 200개 문서 업로드
# 배치 314 완료: 200개 문서 업로드
# 배치 315 완료: 200개 문서 업로드
# 배치 316 완료: 200개 문서 업로드
# 배치 317 완료: 200개 문서 업로드
# 배치 318 완료: 200개 문서 업로드
# 배치 319 완료: 200개 문서 업로드
# 배치 320 완료: 200개 문서 업로드
# 배치 321 완료: 200개 문서 업로드
# 배치 322 완료: 200개 문서 업로드
# 배치 323 완료: 200개 문서 업로드
# 배치 324 완료: 200개 문서 업로드
# 배치 325 완료: 200개 문서 업로드
# 배치 326 완료: 200개 문서 업로드
# 배치 327 완료: 200개 문서 업로드
# 배치 328 완료: 200개 문서 업로드
# 배치 329 완료: 200개 문서 업로드
# 배치 330 완료: 200개 문서 업로드
# 배치 331 완료: 200개 문서 업로드
# 배치 332 완료: 200개 문서 업로드
# 배치 333 완료: 200개 문서 업로드
# 배치 334 완료: 200개 문서 업로드
# 배치 335 완료: 200개 문서 업로드
# 배치 336 완료: 200개 문서 업로드
# 배치 337 완료: 200개 문서 업로드
# 배치 338 완료: 200개 문서 업로드
# 배치 339 완료: 200개 문서 업로드
# 배치 340 완료: 200개 문서 업로드
# 배치 341 완료: 200개 문서 업로드
# 배치 342 완료: 200개 문서 업로드
# 배치 343 완료: 200개 문서 업로드
# 배치 344 완료: 200개 문서 업로드
# 배치 345 완료: 200개 문서 업로드
# 배치 346 완료: 200개 문서 업로드
# 배치 347 완료: 200개 문서 업로드
# 배치 348 완료: 200개 문서 업로드
# 배치 349 완료: 200개 문서 업로드
# 배치 350 완료: 200개 문서 업로드
# 배치 351 완료: 200개 문서 업로드
# 배치 352 완료: 200개 문서 업로드
# 배치 353 완료: 200개 문서 업로드
# 배치 354 완료: 200개 문서 업로드
# 배치 355 완료: 200개 문서 업로드
# 배치 356 완료: 200개 문서 업로드
# 배치 357 완료: 200개 문서 업로드
# 배치 358 완료: 200개 문서 업로드
# 배치 359 완료: 200개 문서 업로드
# 배치 360 완료: 200개 문서 업로드
# 배치 361 완료: 200개 문서 업로드
# 배치 362 완료: 200개 문서 업로드
# 배치 363 완료: 200개 문서 업로드
# 배치 364 완료: 200개 문서 업로드
# 배치 365 완료: 200개 문서 업로드
# 배치 366 완료: 200개 문서 업로드
# 배치 367 완료: 200개 문서 업로드
# 배치 368 완료: 200개 문서 업로드
# 배치 369 완료: 200개 문서 업로드
# 배치 370 완료: 200개 문서 업로드
# 배치 371 완료: 200개 문서 업로드
# 배치 372 완료: 200개 문서 업로드
# 배치 373 완료: 200개 문서 업로드
# 배치 374 완료: 200개 문서 업로드
# 배치 375 완료: 200개 문서 업로드
# 배치 376 완료: 200개 문서 업로드
# 배치 377 완료: 200개 문서 업로드
# 배치 378 완료: 200개 문서 업로드
# 배치 379 완료: 200개 문서 업로드
# 배치 380 완료: 200개 문서 업로드
# 배치 381 완료: 200개 문서 업로드
# 배치 382 완료: 200개 문서 업로드
# 배치 383 완료: 200개 문서 업로드
# 배치 384 완료: 200개 문서 업로드
# 배치 385 완료: 200개 문서 업로드
# 배치 386 완료: 200개 문서 업로드
# 배치 387 완료: 200개 문서 업로드
# 배치 388 완료: 200개 문서 업로드
# 배치 389 완료: 200개 문서 업로드
# 배치 390 완료: 200개 문서 업로드
# 배치 391 완료: 200개 문서 업로드
# 배치 392 완료: 200개 문서 업로드
# 배치 393 완료: 200개 문서 업로드
# 배치 394 완료: 200개 문서 업로드
# 배치 395 완료: 200개 문서 업로드
# 배치 396 완료: 200개 문서 업로드
# 배치 397 완료: 200개 문서 업로드
# 배치 398 완료: 200개 문서 업로드
# 배치 399 완료: 200개 문서 업로드
# 배치 400 완료: 200개 문서 업로드
# 배치 401 완료: 200개 문서 업로드
# 배치 402 완료: 200개 문서 업로드
# 배치 403 완료: 200개 문서 업로드
# 배치 404 완료: 200개 문서 업로드
# 배치 405 완료: 200개 문서 업로드
# 배치 406 완료: 200개 문서 업로드
# 배치 407 완료: 200개 문서 업로드
# 배치 408 완료: 200개 문서 업로드
# 배치 409 완료: 200개 문서 업로드
# 배치 410 완료: 200개 문서 업로드
# 배치 411 완료: 200개 문서 업로드
# 배치 412 완료: 200개 문서 업로드
# 배치 413 완료: 200개 문서 업로드
# 배치 414 완료: 200개 문서 업로드
# 배치 415 완료: 200개 문서 업로드
# 배치 416 완료: 200개 문서 업로드
# 배치 417 완료: 200개 문서 업로드
# 배치 418 완료: 200개 문서 업로드
# 배치 419 완료: 200개 문서 업로드
# 배치 420 완료: 200개 문서 업로드
# 배치 421 완료: 200개 문서 업로드
# 배치 422 완료: 200개 문서 업로드
# 배치 423 완료: 200개 문서 업로드
# 배치 424 완료: 200개 문서 업로드
# 배치 425 완료: 200개 문서 업로드
# 배치 426 완료: 200개 문서 업로드
# 배치 427 완료: 200개 문서 업로드
# 배치 428 완료: 200개 문서 업로드
# 배치 429 완료: 200개 문서 업로드
# 배치 430 완료: 200개 문서 업로드
# 배치 431 완료: 200개 문서 업로드
# 배치 432 완료: 200개 문서 업로드
# 배치 433 완료: 200개 문서 업로드
# 배치 434 완료: 200개 문서 업로드
# 배치 435 완료: 200개 문서 업로드
# 배치 436 완료: 200개 문서 업로드
# 배치 437 완료: 200개 문서 업로드
# 배치 438 완료: 200개 문서 업로드
# 배치 439 완료: 200개 문서 업로드
# 배치 440 완료: 200개 문서 업로드
# 배치 441 완료: 200개 문서 업로드
# 배치 442 완료: 200개 문서 업로드
# 배치 443 완료: 200개 문서 업로드
# 배치 444 완료: 200개 문서 업로드
# 배치 445 완료: 200개 문서 업로드
# 배치 446 완료: 200개 문서 업로드
# 배치 447 완료: 200개 문서 업로드
# 배치 448 완료: 200개 문서 업로드
# 배치 449 완료: 200개 문서 업로드
# 배치 450 완료: 200개 문서 업로드
# 배치 451 완료: 200개 문서 업로드
# 배치 452 완료: 200개 문서 업로드
# 배치 453 완료: 200개 문서 업로드
# 배치 454 완료: 200개 문서 업로드
# 배치 455 완료: 200개 문서 업로드
# 배치 456 완료: 200개 문서 업로드
# 배치 457 완료: 200개 문서 업로드
# 배치 458 완료: 200개 문서 업로드
# 배치 459 완료: 200개 문서 업로드
# 배치 460 완료: 200개 문서 업로드
# 배치 461 완료: 200개 문서 업로드
# 배치 462 완료: 200개 문서 업로드
# 배치 463 완료: 200개 문서 업로드
# 배치 464 완료: 200개 문서 업로드
# 배치 465 완료: 200개 문서 업로드
# 배치 466 완료: 200개 문서 업로드
# 배치 467 완료: 200개 문서 업로드
# 배치 468 완료: 200개 문서 업로드
# 배치 469 완료: 200개 문서 업로드
# 배치 470 완료: 200개 문서 업로드
# 배치 471 완료: 200개 문서 업로드
# 배치 472 완료: 200개 문서 업로드
# 배치 473 완료: 200개 문서 업로드
# 배치 474 완료: 200개 문서 업로드
# 배치 475 완료: 200개 문서 업로드
# 배치 476 완료: 200개 문서 업로드
# 배치 477 완료: 200개 문서 업로드
# 배치 478 완료: 200개 문서 업로드
# 배치 479 완료: 200개 문서 업로드
# 배치 480 완료: 200개 문서 업로드
# 배치 481 완료: 200개 문서 업로드
# 배치 482 완료: 200개 문서 업로드
# 배치 483 완료: 200개 문서 업로드
# 배치 484 완료: 200개 문서 업로드
# 배치 485 완료: 200개 문서 업로드
# 배치 486 완료: 200개 문서 업로드
# 배치 487 완료: 200개 문서 업로드
# 배치 488 완료: 200개 문서 업로드
# 배치 489 완료: 200개 문서 업로드
# 배치 490 완료: 200개 문서 업로드
# 배치 491 완료: 200개 문서 업로드
# 배치 492 완료: 200개 문서 업로드
# 배치 493 완료: 200개 문서 업로드
# 배치 494 완료: 200개 문서 업로드
# 배치 495 완료: 200개 문서 업로드
# 배치 496 완료: 200개 문서 업로드
# 배치 497 완료: 200개 문서 업로드
# 배치 498 완료: 200개 문서 업로드
# 배치 499 완료: 200개 문서 업로드
# 배치 500 완료: 200개 문서 업로드
# 배치 501 완료: 200개 문서 업로드
# 배치 502 완료: 200개 문서 업로드
# 배치 503 완료: 200개 문서 업로드
# 배치 504 완료: 200개 문서 업로드
# 배치 505 완료: 200개 문서 업로드
# 배치 506 완료: 200개 문서 업로드
# 배치 507 완료: 200개 문서 업로드
# 배치 508 완료: 200개 문서 업로드
# 배치 509 완료: 200개 문서 업로드
# 배치 510 완료: 200개 문서 업로드
# 배치 511 완료: 200개 문서 업로드
# 배치 512 완료: 200개 문서 업로드
# 배치 513 완료: 200개 문서 업로드
# 배치 514 완료: 200개 문서 업로드
# 배치 515 완료: 200개 문서 업로드
# 배치 516 완료: 200개 문서 업로드
# 배치 517 완료: 200개 문서 업로드
# 배치 518 완료: 200개 문서 업로드
# 배치 519 완료: 200개 문서 업로드
# 배치 520 완료: 200개 문서 업로드
# 배치 521 완료: 200개 문서 업로드
# 배치 522 완료: 200개 문서 업로드
# 배치 523 완료: 200개 문서 업로드
# 배치 524 완료: 200개 문서 업로드
# 배치 525 완료: 200개 문서 업로드
# 배치 526 완료: 200개 문서 업로드
# 배치 527 완료: 200개 문서 업로드
# 배치 528 완료: 200개 문서 업로드
# 배치 529 완료: 200개 문서 업로드
# 배치 530 완료: 200개 문서 업로드
# 배치 531 완료: 200개 문서 업로드
# 배치 532 완료: 200개 문서 업로드
# 배치 533 완료: 200개 문서 업로드
# 배치 534 완료: 200개 문서 업로드
# 배치 535 완료: 200개 문서 업로드
# 배치 536 완료: 200개 문서 업로드
# 배치 537 완료: 200개 문서 업로드
# 배치 538 완료: 200개 문서 업로드
# 배치 539 완료: 200개 문서 업로드
# 배치 540 완료: 200개 문서 업로드
# 배치 541 완료: 200개 문서 업로드
# 배치 542 완료: 200개 문서 업로드
# 배치 543 완료: 200개 문서 업로드
# 배치 544 완료: 200개 문서 업로드
# 배치 545 완료: 200개 문서 업로드
# 배치 546 완료: 200개 문서 업로드
# 배치 547 완료: 200개 문서 업로드
# 배치 548 완료: 200개 문서 업로드
# 배치 549 완료: 200개 문서 업로드
# 배치 550 완료: 200개 문서 업로드
# 배치 551 완료: 200개 문서 업로드
# 배치 552 완료: 200개 문서 업로드
# 배치 553 완료: 200개 문서 업로드
# 배치 554 완료: 200개 문서 업로드
# 배치 555 완료: 200개 문서 업로드
# 배치 556 완료: 200개 문서 업로드
# 배치 557 완료: 200개 문서 업로드
# 배치 558 완료: 200개 문서 업로드
# 배치 559 완료: 200개 문서 업로드
# 배치 560 완료: 200개 문서 업로드
# 배치 561 완료: 200개 문서 업로드
# 배치 562 완료: 200개 문서 업로드
# 배치 563 완료: 200개 문서 업로드
# 배치 564 완료: 200개 문서 업로드
# 배치 565 완료: 200개 문서 업로드
# 배치 566 완료: 200개 문서 업로드
# 배치 567 완료: 200개 문서 업로드
# 배치 568 완료: 200개 문서 업로드
# 배치 569 완료: 200개 문서 업로드
# 배치 570 완료: 200개 문서 업로드
# 배치 571 완료: 200개 문서 업로드
# 배치 572 완료: 200개 문서 업로드
# 배치 573 완료: 200개 문서 업로드
# 배치 574 완료: 200개 문서 업로드
# 배치 575 완료: 200개 문서 업로드
# 배치 576 완료: 200개 문서 업로드
# 배치 577 완료: 200개 문서 업로드
# 배치 578 완료: 200개 문서 업로드
# 배치 579 완료: 200개 문서 업로드
# 배치 580 완료: 200개 문서 업로드
# 배치 581 완료: 200개 문서 업로드
# 배치 582 완료: 200개 문서 업로드
# 배치 583 완료: 200개 문서 업로드
# 배치 584 완료: 200개 문서 업로드
# 배치 585 완료: 200개 문서 업로드
# 배치 586 완료: 200개 문서 업로드
# 배치 587 완료: 200개 문서 업로드
# 배치 588 완료: 200개 문서 업로드
# 배치 589 완료: 200개 문서 업로드
# 배치 590 완료: 200개 문서 업로드
# 배치 591 완료: 200개 문서 업로드
# 배치 592 완료: 200개 문서 업로드
# 배치 593 완료: 200개 문서 업로드
# 배치 594 완료: 200개 문서 업로드
# 배치 595 완료: 200개 문서 업로드
# 배치 596 완료: 200개 문서 업로드
# 배치 597 완료: 200개 문서 업로드
# 배치 598 완료: 200개 문서 업로드
# 배치 599 완료: 200개 문서 업로드
# 배치 600 완료: 200개 문서 업로드
# 배치 601 완료: 200개 문서 업로드
# 배치 602 완료: 200개 문서 업로드
# 배치 603 완료: 200개 문서 업로드
# 배치 604 완료: 200개 문서 업로드
# 배치 605 완료: 200개 문서 업로드
# 배치 606 완료: 200개 문서 업로드
# 배치 607 완료: 200개 문서 업로드
# 배치 608 완료: 200개 문서 업로드
# 배치 609 완료: 200개 문서 업로드
# 배치 610 완료: 200개 문서 업로드
# 배치 611 완료: 200개 문서 업로드
# 배치 612 완료: 200개 문서 업로드
# 배치 613 완료: 200개 문서 업로드
# 배치 614 완료: 200개 문서 업로드
# 배치 615 완료: 200개 문서 업로드
# 배치 616 완료: 200개 문서 업로드
# 배치 617 완료: 200개 문서 업로드
# 배치 618 완료: 200개 문서 업로드
# 배치 619 완료: 200개 문서 업로드
# 배치 620 완료: 200개 문서 업로드
# 배치 621 완료: 200개 문서 업로드
# 배치 622 완료: 200개 문서 업로드
# 배치 623 완료: 200개 문서 업로드
# 배치 624 완료: 200개 문서 업로드
# 배치 625 완료: 200개 문서 업로드
# 배치 626 완료: 200개 문서 업로드
# 배치 627 완료: 200개 문서 업로드
# 배치 628 완료: 200개 문서 업로드
# 배치 629 완료: 200개 문서 업로드
# 배치 630 완료: 200개 문서 업로드
# 배치 631 완료: 200개 문서 업로드
# 배치 632 완료: 200개 문서 업로드
# 배치 633 완료: 200개 문서 업로드
# 배치 634 완료: 200개 문서 업로드
# 배치 635 완료: 200개 문서 업로드
# 배치 636 완료: 200개 문서 업로드
# 배치 637 완료: 200개 문서 업로드
# 배치 638 완료: 200개 문서 업로드
# 배치 639 완료: 200개 문서 업로드
# 배치 640 완료: 200개 문서 업로드
# 배치 641 완료: 200개 문서 업로드
# 배치 642 완료: 200개 문서 업로드
# 배치 643 완료: 200개 문서 업로드
# 배치 644 완료: 200개 문서 업로드
# 배치 645 완료: 200개 문서 업로드
# 배치 646 완료: 200개 문서 업로드
# 배치 647 완료: 200개 문서 업로드
# 배치 648 완료: 200개 문서 업로드
# 배치 649 완료: 200개 문서 업로드
# 배치 650 완료: 182개 문서 업로드
